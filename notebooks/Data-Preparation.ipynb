# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sqlite3

# Connect to Database
con = sqlite3.connect('../data/raw/database.db') 
cur = con.cursor()

# %%
# read column names
columns = []
for idx, name, col_type, *args in cur.execute("PRAGMA table_info('listings');").fetchall():
    columns.append(name)
columns[:5]
# Out:
# ['user_id', 'id', 'uri', 'title', 'price']

# %%
# read table content
sql_query = pd.read_sql('SELECT * FROM listings', con)

# Convert SQL to DataFrame
df = pd.DataFrame(sql_query, columns=columns)

df.head()
# Out:
#    user_id    id                                                uri  \
# 0    10065  4331                  شارع-الياقوت-الدار-البيضاء-الرياض
# 1    11005  4837  طريق-الملك-عبدالله-بن-عبدالعزيز-الفرعي-المغرزا...
# 2     8017  5498                    5-المملكة-العربية-السعودية-5498
# 3    13810  6520                      شارع-Saher-Al-Garbee-St-ذهبان
# 4     5234  8847         طريق-الملك-خالد-حي-الثقبة-الخبر-الخبر-8847
#
#                                                title       price  \
# 0   أرض للبيع في شارع الياقوت, الدار البيضاء, الرياض   1958400.0
# 1  أرض للبيع في طريق الملك عبدالله بن عبدالعزيز ا...  15078000.0
# 2            أرض للبيع في 5 المملكة العربية السعودية   8057700.0
# 3     أرض للإيجار في شارع الهزاعية, حي العشيرية, جدة     50000.0
# 4  أرض للبيع في طريق الملك خالد ، حي الثقبة ، الخ...   3000000.0
#
#                                              content  \
# 0                 تجاريه ش ياقوت ٦٠ مساحه ٨١٦ تقريبا
# 1  الارض على طريق الملك عبدالله على شارعين مظاهره...
# 2  الارض استثماريه في محافظة البرك طريق جده جازان...
# 3  السلام عليكم ورحمة الله وبركاته\nوكل عام وانتم...
# 4  ارض للبيع لبناء شقق فندقيه او عمارات سكنيه خلف...
#
#                                                 imgs     refresh  category  \
# 0                    ["000000000_1627687178830.jpg"]  1672495809         2
# 1                    ["000000000_1627687181813.jpg"]  1672040788         2
# 2  ["506610555_1417214243205.jpg","506610555_1417...  1671819056         2
# 3  ["504121665_1418232181483.jpg","504121665_1418...  1672190424        15
# 4  ["567772202_1632148243568.png","000052346_1661...  1672253180         2
#
#    beds  ...          district  district_id  width  length  advertiser_type  \
# 0   0.0  ...  حي الدار البيضاء          424   25.0    32.0             None
# 1   0.0  ...       حي المغرزات          566    NaN     NaN             None
# 2   0.0  ...         حي الروضة         4100    NaN     NaN             None
# 3   0.0  ...         حي الرياض         3490   20.0    20.0             None
# 4   0.0  ...         حي الثقبة         1060    NaN     NaN             None
#
#    create_time  has_extended_details  daily_rentable  \
# 0   1415294130                   NaN             0.0
# 1   1416054461                   NaN             0.0
# 2   1417220044                   NaN             0.0
# 3   1418232587                   NaN             0.0
# 4   1420232812                   NaN             0.0
#
#                         createdAt                       updatedAt
# 0  2023-01-01 14:13:28.553 +00:00  2023-01-01 14:13:28.553 +00:00
# 1  2023-01-01 14:52:38.169 +00:00  2023-01-01 14:52:38.169 +00:00
# 2  2023-01-01 15:01:52.351 +00:00  2023-01-01 15:01:52.351 +00:00
# 3  2023-01-01 14:43:23.326 +00:00  2023-01-01 14:43:23.326 +00:00
# 4  2023-01-01 14:38:46.004 +00:00  2023-01-01 14:38:46.004 +00:00
#
# [5 rows x 48 columns]

# %% [markdown]
# ### Data cleaning

# %%
# look at None statistics
nan_info = df.isna().sum()
nan_info
# Out:
# user_id                      0
# id                           0
# uri                          0
# title                       21
# price                        0
# content                    230
# imgs                         0
# refresh                      0
# category                     0
# beds                    252609
# livings                 252119
# wc                      254128
# area                       577
# type                    502773
# street_width             18982
# age                     253127
# last_update                  0
# street_direction         94891
# ketchen                 277809
# ac                      555898
# furnished               238949
# location.lat                 0
# location.lng                 0
# path                         0
# user.review             118066
# user.img                222565
# user.name                 6285
# user.phone                   0
# user.iam_verified         3714
# user.rega_id            338325
# native.logo             663944
# native.title            663944
# native.image            663946
# native.description      663944
# native.external_url     663946
# rent_period             571232
# city                         0
# city_id                      0
# district                     0
# district_id                  0
# width                    57444
# length                   57641
# advertiser_type          23932
# create_time                  0
# has_extended_details    653524
# daily_rentable          315493
# createdAt                    0
# updatedAt                    0
# dtype: int64

# %%
# colums to remove entirely
remove_cols = [
    # too few values
    'native.logo', 'native.title', 'native.image', 'native.description', 'native.external_url',
    
    # too unique/can lead to bias
    'user.phone', 'user.rega_id', 'user_id', 'id',
    
    # invalid data type
    'user.img', 'uri', 'user.name', 'city', 'district', 'imgs', 'path',
    
    # invalid data type, but might be considered usefull with interpretable NLP
    'content', 'title',
    
    # website time data
    'last_update', 'create_time', 'createdAt', 'updatedAt', 'refresh',
    
    # strongly correlated with any other column
    'width', 'length',
    
    # unexplainable features
    'type'
]

# %%
df_dropped = df.drop(columns=remove_cols)
df_dropped.isna().sum()
# Out:
# price                        0
# category                     0
# beds                    252609
# livings                 252119
# wc                      254128
# area                       577
# street_width             18982
# age                     253127
# street_direction         94891
# ketchen                 277809
# ac                      555898
# furnished               238949
# location.lat                 0
# location.lng                 0
# user.review             118066
# user.iam_verified         3714
# rent_period             571232
# city_id                      0
# district_id                  0
# advertiser_type          23932
# has_extended_details    653524
# daily_rentable          315493
# dtype: int64

# %%
def print_stats(column_name: str):
    print('----', column_name, '----')
    print(df[column_name].mean(), df[column_name].median())
    print(df[column_name].unique())
    

for column_name in df_dropped.columns:
    if column_name == 'advertiser_type':
        continue
    print_stats(column_name)
# Out:
# ---- price ----
# 3986665.0763846464 1000000.0
# [ 1958400. 15078000.  8057700. ...  3939488.  1871500.  4367190.]
# ---- category ----
# 4.148884095995759 3.0
# [ 2 15 16  3  7  8  6 12  1  9 19 13 10 21 14 17  5 20 18  4 22 11 23]
# ---- beds ----
# 4.273299022456039 4.0
# [ 0.  5.  2.  1.  3.  7.  4.  6. nan]
# ---- livings ----
# 1.7240710298256308 1.0
# [ 0.  3.  1.  2.  4.  5. nan  6.  7.]
# ---- wc ----
# 3.723467490446979 4.0
# [ 0.  5.  3.  2.  1.  4. nan]
# ---- area ----
# 5686.021250616173 350.0
# [  816.  1077. 23022. ... 25852. 10595. 10520.]
# ---- street_width ----
# 21.786454747861896 20.0
# [ 60.  80.  15.  35.  30.  40.  25.  65.  12.   8.  50.  20.   0.  32.
#  100.  52.   5.  70.  10.  45.  16.  29.  55.   4.  nan  58.  36.  11.
#   22.  24.  21.   7.  42.  31.  95.  17.  14.  28.  64.  26.  27.  13.
#    9.  85.  19.  18.  23.  34.   6.  33.  61.  49.  44.  56.  90.  41.
#   38.  51.  75.  37.   2.  62.   1.  99.  84.  74.  71.  46.  43.  39.
#   59.  54.  72.  47.  57.  79.  53.   3.  63.  69.  81.  83.  48.  82.
#   86.  98.  97.  66.  73.  88.  91.  96.  92.  89.  68.  93.  78.  67.
#   94.  77.  76.  87.]
# ---- age ----
# 3.7886417132605845 0.0
# [ 0.  3. 15. 25. 27.  6. 10.  5. 12. 18. 30.  2. 20.  1.  4. 36.  9.  8.
#  11. 35. 32. 24. 14. 13.  7. nan 28. 19. 22. 33. 29. 34. 16. 23. 26. 17.
#  31. 21.]
# ---- street_direction ----
# 3.3496814894869567 3.0
# [ 4.  3.  7.  8.  2.  5.  1. 10.  0.  9.  6. nan]
# ---- ketchen ----
# 0.9278105957212077 1.0
# [ 0.  1. nan]
# ---- ac ----
# 0.5407411520805568 1.0
# [ 0.  1. nan]
# ---- furnished ----
# 0.08520766028936674 0.0
# [ 0.  1. nan]
# ---- location.lat ----
# 24.156012473532158 24.7644865
# [24.54893  24.75413  18.26872  ... 26.153383 26.363222 24.885909]
# ---- location.lng ----
# 45.158953541909916 46.619579
# [46.78139  46.72482  41.51646  ... 50.213308 46.71265  46.6564  ]
# ---- user.review ----
# 4.413296365501575 4.45
# [3.83 4.56  nan 4.43 4.76 4.08 4.7  3.86 4.5  4.55 4.35 5.   4.   4.53
#  3.75 4.19 4.83 4.63 4.26 4.87 4.33 4.36 4.52 3.82 4.82 4.47 3.28 4.9
#  4.45 4.66 4.67 3.   4.38 4.32 4.74 3.78 4.14 4.69 4.15 4.86 4.2  4.46
#  3.85 4.39 4.6  4.51 4.22 4.75 3.8  4.73 4.34 4.62 4.28 4.05 4.68 4.49
#  3.98 3.67 4.17 4.42 4.4  4.65 4.59 4.48 4.37 4.18 3.93 4.71 1.   3.79
#  4.58 4.29 4.1  4.44 3.95 4.3  4.04 4.09 4.8  4.07 4.85 4.06 2.33 3.25
#  4.16 4.03 4.77 2.75 4.21 3.33 4.95 4.57 4.23 4.31 3.72 4.13 3.7  3.74
#  4.61 4.54 3.29 4.27 3.88 3.45 3.89 4.41 3.56 4.25 4.24 4.93 3.71 4.88
#  4.64 4.91 4.11 3.5  3.4  3.73 3.9  4.81 2.14 3.47 3.94 3.96 3.84 3.64
#  4.72 3.55 4.78 3.63 4.79 2.   3.77 3.92 3.6  3.81 3.42 4.89 3.99 4.92
#  3.91 4.84 3.38 3.62 3.87 3.54 4.12 2.67 3.61 2.5  3.43 4.97 4.94 3.27
#  3.97 3.58 3.57 2.8  3.41 4.02 4.01 3.46 1.8  3.22 3.15 3.26 4.96 3.76
#  3.48 3.59 3.31 3.53 3.2  3.23 3.44 3.68 3.17 2.25 2.6  3.69 3.35 3.18
#  3.36 2.42 1.67 2.17 3.32 3.37 3.52 2.43 3.49 3.66 3.39 1.75 3.14 2.7
#  2.63 3.65 2.2  2.97 3.08 3.13 2.56 2.95 2.89 1.5  2.9  2.83 3.3  3.19
#  3.06 3.09 2.82 3.1  2.93 3.03 3.21 3.51 4.98 2.86 2.96 3.24 2.85 2.78
#  2.73 2.4  2.22 2.57 1.33 2.71 0.   0.5  3.34 2.88 3.05 2.72 1.86 3.04]
# ---- user.iam_verified ----
# 0.9894340171333713 1.0
# [ 1.  0. nan]
# ---- rent_period ----
# 2.6906616045041742 3.0
# [ 0.  3.  1.  2. nan]
# ---- city_id ----
# 33.344580733975356 21.0
# [21 92 66 12 18 41 94 26  1  9 65 93 16 43 46 56  6 28 52 91 63 13 73  3
#  27 34  8 68 97 74 67 70 69 54 64 72 84  2 40 59 45 22 33 11 88 78 96  4
#  39 24 80  7 85 36 20 77 17 44 95 35 79  5 25 10 89 47 71 29 19 55 60 61
#  42 30 82 57 53 31 15 23 62 37 14 50 76 86 75 51 81 48 83 38 32 58 87 90
#  49]
# ---- district_id ----
# 1476.007940404792 682.0
# [ 424  566 4100 ...  300 3222 4414]
# ---- has_extended_details ----
# 1.0 1.0
# [nan  1.]
# ---- daily_rentable ----
# 0.0007318060111406703 0.0
# [ 0. nan  1.]

# %%
non_imputable = ['beds', 'livings', 'wc', 'ac', 'ketchen', 'furnished', 'advertiser_type']  # advertiser_type influence a lot

df_notna = df_dropped.copy()
for column_name in non_imputable:
    df_notna = df_notna[df_notna[column_name].notna()]
df_notna
# Out:
#           price  category  beds  livings   wc       area  street_width   age  \
# 2308     5500.0         1   1.0      1.0  1.0        NaN           NaN   2.0
# 2366     2000.0         1   3.0      1.0  1.0        NaN           NaN   0.0
# 2369    18000.0         1   5.0      1.0  4.0  3000000.0           NaN  15.0
# 2405    50000.0         5   7.0      2.0  5.0      900.0          30.0  30.0
# 2434     1500.0         1   1.0      1.0  1.0       50.0           5.0   NaN
# ...         ...       ...   ...      ...  ...        ...           ...   ...
# 663918  32000.0         1   4.0      2.0  2.0      160.0          23.0  10.0
# 663924  35000.0         1   3.0      1.0  2.0      160.0          18.0   9.0
# 663925  25000.0         1   3.0      1.0  2.0      125.0           NaN   NaN
# 663938  50000.0         1   2.0      2.0  2.0      250.0           5.0  15.0
# 663939  26400.0         1   4.0      1.0  3.0      150.0           5.0  17.0
#
#         street_direction  ketchen  ...  location.lat  location.lng  \
# 2308                 NaN      1.0  ...     24.673321     46.696861
# 2366                 NaN      1.0  ...     20.040100     41.485947
# 2369                 NaN      1.0  ...     27.527849     41.652676
# 2405                 8.0      0.0  ...     26.361073     43.995518
# 2434                 NaN      1.0  ...     24.165192     47.322449
# ...                  ...      ...  ...           ...           ...
# 663918               NaN      1.0  ...     21.649360     39.139800
# 663924               NaN      1.0  ...     21.516285     39.226463
# 663925               2.0      0.0  ...     24.927849     46.800327
# 663938               NaN      1.0  ...     24.795143     46.703434
# 663939               NaN      0.0  ...     21.399612     39.299591
#
#         user.review  user.iam_verified  rent_period  city_id  district_id  \
# 2308           4.56                1.0          2.0       21          506
# 2366           4.70                1.0          2.0        5         4434
# 2369           5.00                1.0          3.0       67         2058
# 2405           4.74                1.0          3.0       52         2370
# 2434           4.40                1.0          2.0       13          282
# ...             ...                ...          ...      ...          ...
# 663918         4.46                1.0          3.0       66         3578
# 663924         5.00                1.0          3.0       66         3604
# 663925         4.03                1.0          3.0       21          446
# 663938          NaN                1.0          3.0       21          522
# 663939          NaN                1.0          2.0       66         3428
#
#            advertiser_type  has_extended_details daily_rentable
# 2308    exclusive_marketer                   NaN            0.0
# 2366                 agent                   NaN            0.0
# 2369    exclusive_marketer                   NaN            0.0
# 2405    exclusive_marketer                   NaN            0.0
# 2434                 owner                   NaN            0.0
# ...                    ...                   ...            ...
# 663918  exclusive_marketer                   NaN            NaN
# 663924               owner                   NaN            NaN
# 663925               agent                   1.0            NaN
# 663938               owner                   NaN            NaN
# 663939               owner                   1.0            NaN
#
# [91501 rows x 22 columns]

# %%
# number of rows lost
df_dropped.shape, df_notna.shape
# Out:
# ((663946, 22), (91501, 22))

# %%
df_notna.isna().sum()
# Out:
# price                       0
# category                    0
# beds                        0
# livings                     0
# wc                          0
# area                      329
# street_width             1273
# age                     11684
# street_direction        75541
# ketchen                     0
# ac                          0
# furnished                   0
# location.lat                0
# location.lng                0
# user.review             16586
# user.iam_verified         406
# rent_period             15022
# city_id                     0
# district_id                 0
# advertiser_type             0
# has_extended_details    89375
# daily_rentable          61517
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# impute special values
df_imputed = df_notna.copy()
df_imputed['has_extended_details'] = df_imputed['has_extended_details'].fillna(0)

# impute by median
median_columns = ['area', 'street_width', 'age', 'street_direction', 'user.review']
for column_name in median_columns:
    median = df_imputed[column_name].median()
    df_imputed[column_name] = df_imputed[column_name].fillna(median)

df_imputed
# Out:
#           price  category  beds  livings   wc       area  street_width   age  \
# 2308     5500.0         1   1.0      1.0  1.0      160.0          18.0   2.0
# 2366     2000.0         1   3.0      1.0  1.0      160.0          18.0   0.0
# 2369    18000.0         1   5.0      1.0  4.0  3000000.0          18.0  15.0
# 2405    50000.0         5   7.0      2.0  5.0      900.0          30.0  30.0
# 2434     1500.0         1   1.0      1.0  1.0       50.0           5.0   2.0
# ...         ...       ...   ...      ...  ...        ...           ...   ...
# 663918  32000.0         1   4.0      2.0  2.0      160.0          23.0  10.0
# 663924  35000.0         1   3.0      1.0  2.0      160.0          18.0   9.0
# 663925  25000.0         1   3.0      1.0  2.0      125.0          18.0   2.0
# 663938  50000.0         1   2.0      2.0  2.0      250.0           5.0  15.0
# 663939  26400.0         1   4.0      1.0  3.0      150.0           5.0  17.0
#
#         street_direction  ketchen  ...  location.lat  location.lng  \
# 2308                 3.0      1.0  ...     24.673321     46.696861
# 2366                 3.0      1.0  ...     20.040100     41.485947
# 2369                 3.0      1.0  ...     27.527849     41.652676
# 2405                 8.0      0.0  ...     26.361073     43.995518
# 2434                 3.0      1.0  ...     24.165192     47.322449
# ...                  ...      ...  ...           ...           ...
# 663918               3.0      1.0  ...     21.649360     39.139800
# 663924               3.0      1.0  ...     21.516285     39.226463
# 663925               2.0      0.0  ...     24.927849     46.800327
# 663938               3.0      1.0  ...     24.795143     46.703434
# 663939               3.0      0.0  ...     21.399612     39.299591
#
#         user.review  user.iam_verified  rent_period  city_id  district_id  \
# 2308           4.56                1.0          2.0       21          506
# 2366           4.70                1.0          2.0        5         4434
# 2369           5.00                1.0          3.0       67         2058
# 2405           4.74                1.0          3.0       52         2370
# 2434           4.40                1.0          2.0       13          282
# ...             ...                ...          ...      ...          ...
# 663918         4.46                1.0          3.0       66         3578
# 663924         5.00                1.0          3.0       66         3604
# 663925         4.03                1.0          3.0       21          446
# 663938         4.49                1.0          3.0       21          522
# 663939         4.49                1.0          2.0       66         3428
#
#            advertiser_type  has_extended_details daily_rentable
# 2308    exclusive_marketer                   0.0            0.0
# 2366                 agent                   0.0            0.0
# 2369    exclusive_marketer                   0.0            0.0
# 2405    exclusive_marketer                   0.0            0.0
# 2434                 owner                   0.0            0.0
# ...                    ...                   ...            ...
# 663918  exclusive_marketer                   0.0            NaN
# 663924               owner                   0.0            NaN
# 663925               agent                   1.0            NaN
# 663938               owner                   0.0            NaN
# 663939               owner                   1.0            NaN
#
# [91501 rows x 22 columns]

# %%
# find outliers by different values
from sklearn.ensemble import IsolationForest
import numpy as np

possible_outliers = ['area', 'price']

vals = np.array([0] * df_imputed.shape[0])
for column_name in possible_outliers:
    clf = IsolationForest(n_estimators=100, warm_start=False, bootstrap=True, contamination=0.0025, random_state=42)
    vals += clf.fit_predict(df_imputed[column_name].to_numpy().reshape(-1, 1))

# %%
df_filtered = df_imputed[vals == 2]

df_imputed[vals != 2]
# Out:
#              price  category  beds  livings   wc       area  street_width  \
# 2369       18000.0         1   5.0      1.0  4.0  3000000.0          18.0
# 6080     3200000.0         3   4.0      2.0  4.0      375.0          20.0
# 7796     3000000.0         7   1.0      0.0  0.0      720.0          40.0
# 9781    15000000.0         3   7.0      4.0  5.0     1350.0          20.0
# 11080    2677500.0         2   2.0      1.0  3.0      450.0          15.0
# ...            ...       ...   ...      ...  ...        ...           ...
# 660843     19200.0         1   4.0      1.0  3.0    14140.0          30.0
# 662110     22000.0         1   5.0      1.0  3.0   100000.0           5.0
# 662672      2500.0         1   1.0      1.0  2.0    30000.0           5.0
# 663485  13200000.0         7   6.0      2.0  5.0      990.0          18.0
# 663601     40000.0         1   3.0      1.0  3.0    25852.0           5.0
#
#          age  street_direction  ketchen  ...  location.lat  location.lng  \
# 2369    15.0               3.0      1.0  ...     27.527849     41.652676
# 6080     4.0               1.0      1.0  ...     24.776247     46.655800
# 7796     6.0               2.0      1.0  ...     24.818441     46.877065
# 9781    15.0               5.0      1.0  ...     24.744841     46.617371
# 11080    7.0               1.0      1.0  ...     24.810245     46.593656
# ...      ...               ...      ...  ...           ...           ...
# 660843   2.0               3.0      1.0  ...     18.259188     42.764233
# 662110   2.0               3.0      0.0  ...     24.516800     39.567139
# 662672   2.0               3.0      1.0  ...     18.212112     42.511906
# 663485   2.0               1.0      1.0  ...     21.497988     39.272816
# 663601   2.0               3.0      1.0  ...     24.640747     46.554287
#
#         user.review  user.iam_verified  rent_period  city_id  district_id  \
# 2369           5.00                1.0          3.0       67         2058
# 6080           4.77                1.0          3.0       21          514
# 7796           4.38                1.0          NaN       21          410
# 9781           4.33                1.0          3.0       21          596
# 11080          3.00                1.0          3.0       21          570
# ...             ...                ...          ...      ...          ...
# 660843         5.00                1.0          3.0       70         4060
# 662110         5.00                1.0          3.0       41         2968
# 662672         4.49                1.0          2.0        1         3822
# 663485         4.57                1.0          NaN       66         3426
# 663601         5.00                1.0          3.0       21          688
#
#            advertiser_type  has_extended_details daily_rentable
# 2369    exclusive_marketer                   0.0            0.0
# 6080                 agent                   0.0            0.0
# 7796       normal_marketer                   0.0            0.0
# 9781    exclusive_marketer                   0.0            0.0
# 11080      normal_marketer                   0.0            0.0
# ...                    ...                   ...            ...
# 660843               owner                   0.0            NaN
# 662110               owner                   0.0            NaN
# 662672               owner                   0.0            NaN
# 663485               agent                   1.0            NaN
# 663601               owner                   0.0            NaN
#
# [431 rows x 22 columns]

# %%
df_filtered
# Out:
#           price  category  beds  livings   wc   area  street_width   age  \
# 2308     5500.0         1   1.0      1.0  1.0  160.0          18.0   2.0
# 2366     2000.0         1   3.0      1.0  1.0  160.0          18.0   0.0
# 2405    50000.0         5   7.0      2.0  5.0  900.0          30.0  30.0
# 2434     1500.0         1   1.0      1.0  1.0   50.0           5.0   2.0
# 2435     1500.0         1   1.0      1.0  1.0  160.0          18.0   2.0
# ...         ...       ...   ...      ...  ...    ...           ...   ...
# 663918  32000.0         1   4.0      2.0  2.0  160.0          23.0  10.0
# 663924  35000.0         1   3.0      1.0  2.0  160.0          18.0   9.0
# 663925  25000.0         1   3.0      1.0  2.0  125.0          18.0   2.0
# 663938  50000.0         1   2.0      2.0  2.0  250.0           5.0  15.0
# 663939  26400.0         1   4.0      1.0  3.0  150.0           5.0  17.0
#
#         street_direction  ketchen  ...  location.lat  location.lng  \
# 2308                 3.0      1.0  ...     24.673321     46.696861
# 2366                 3.0      1.0  ...     20.040100     41.485947
# 2405                 8.0      0.0  ...     26.361073     43.995518
# 2434                 3.0      1.0  ...     24.165192     47.322449
# 2435                 3.0      1.0  ...     24.166740     47.325615
# ...                  ...      ...  ...           ...           ...
# 663918               3.0      1.0  ...     21.649360     39.139800
# 663924               3.0      1.0  ...     21.516285     39.226463
# 663925               2.0      0.0  ...     24.927849     46.800327
# 663938               3.0      1.0  ...     24.795143     46.703434
# 663939               3.0      0.0  ...     21.399612     39.299591
#
#         user.review  user.iam_verified  rent_period  city_id  district_id  \
# 2308           4.56                1.0          2.0       21          506
# 2366           4.70                1.0          2.0        5         4434
# 2405           4.74                1.0          3.0       52         2370
# 2434           4.40                1.0          2.0       13          282
# 2435           4.40                1.0          2.0       13          282
# ...             ...                ...          ...      ...          ...
# 663918         4.46                1.0          3.0       66         3578
# 663924         5.00                1.0          3.0       66         3604
# 663925         4.03                1.0          3.0       21          446
# 663938         4.49                1.0          3.0       21          522
# 663939         4.49                1.0          2.0       66         3428
#
#            advertiser_type  has_extended_details daily_rentable
# 2308    exclusive_marketer                   0.0            0.0
# 2366                 agent                   0.0            0.0
# 2405    exclusive_marketer                   0.0            0.0
# 2434                 owner                   0.0            0.0
# 2435                 owner                   0.0            0.0
# ...                    ...                   ...            ...
# 663918  exclusive_marketer                   0.0            NaN
# 663924               owner                   0.0            NaN
# 663925               agent                   1.0            NaN
# 663938               owner                   0.0            NaN
# 663939               owner                   1.0            NaN
#
# [91070 rows x 22 columns]

# %% [markdown]
# ### Data Integration

# %%
df_modified = df_filtered.copy()


"""
1= Apartment, rental | 
6= Apartment, sell | 
21= Furnished apartment |

2= Land, sell | 
15= Land, rental |

3= Villa, sell |
5= Villa, rental | 

4= Floor, rental | 
22= Floor, sell | 

7= Building, sell | 
16= Building, rental |

8= Store, rental |
20= Store, sell |

9= House, sell | 
11= House, rental | 

10= Esterahah, sell | 
13= Esterahah, rental | 

12= Farm, sell | 

14= Office, rental | 

17= Warehouse, rental | 

18= Campsite, rental | 

19= Room, rental |

23= Chalet, rental

"""

df_modified['number_of_rooms'] = df_modified['beds'] + df_modified['livings'] + df_modified['wc']

df_modified['is_appartement'] = df_modified['category'].isin([1, 6, 21])
df_modified['is_land'] = df_modified['category'].isin([2, 15])
df_modified['is_villa'] = df_modified['category'].isin([3, 5])
df_modified['is_floot'] = df_modified['category'].isin([4, 22])
df_modified['is_building'] = df_modified['category'].isin([7, 16])
df_modified['is_store'] = df_modified['category'].isin([8, 20])
df_modified['is_house'] = df_modified['category'].isin([9, 11])
df_modified['is_esterahah'] = df_modified['category'].isin([10, 13])
df_modified['is_farm'] = df_modified['category'].isin([12])
df_modified['is_office'] = df_modified['category'].isin([14])
df_modified['is_warehouse'] = df_modified['category'].isin([17])
df_modified['is_campsite'] = df_modified['category'].isin([18])
df_modified['is_room'] = df_modified['category'].isin([19])
df_modified['is_chalet'] = df_modified['category'].isin([23])

df_modified['is_sell'] = df_modified['category'].isin([6, 2, 3, 22, 7, 20, 9, 10, 12])
df_modified['is_rent'] = df_modified['category'].isin([1, 21, 15, 5, 4, 16, 8, 13, 14, 17, 18, 19, 23, 11])

df_modified['all_inclusive'] = \
        (df_modified['beds'] > 0) & \
        (df_modified['livings'] > 0) & \
        (df_modified['wc'] > 0) & \
        (df_modified['ketchen'] > 0) & \
        (df_modified['ac'] > 0) & \
        (df_modified['furnished'] > 0)
        

df_modified
# Out:
#           price  category  beds  livings   wc   area  street_width   age  \
# 2308     5500.0         1   1.0      1.0  1.0  160.0          18.0   2.0
# 2366     2000.0         1   3.0      1.0  1.0  160.0          18.0   0.0
# 2405    50000.0         5   7.0      2.0  5.0  900.0          30.0  30.0
# 2434     1500.0         1   1.0      1.0  1.0   50.0           5.0   2.0
# 2435     1500.0         1   1.0      1.0  1.0  160.0          18.0   2.0
# ...         ...       ...   ...      ...  ...    ...           ...   ...
# 663918  32000.0         1   4.0      2.0  2.0  160.0          23.0  10.0
# 663924  35000.0         1   3.0      1.0  2.0  160.0          18.0   9.0
# 663925  25000.0         1   3.0      1.0  2.0  125.0          18.0   2.0
# 663938  50000.0         1   2.0      2.0  2.0  250.0           5.0  15.0
# 663939  26400.0         1   4.0      1.0  3.0  150.0           5.0  17.0
#
#         street_direction  ketchen  ...  is_esterahah  is_farm  is_office  \
# 2308                 3.0      1.0  ...         False    False      False
# 2366                 3.0      1.0  ...         False    False      False
# 2405                 8.0      0.0  ...         False    False      False
# 2434                 3.0      1.0  ...         False    False      False
# 2435                 3.0      1.0  ...         False    False      False
# ...                  ...      ...  ...           ...      ...        ...
# 663918               3.0      1.0  ...         False    False      False
# 663924               3.0      1.0  ...         False    False      False
# 663925               2.0      0.0  ...         False    False      False
# 663938               3.0      1.0  ...         False    False      False
# 663939               3.0      0.0  ...         False    False      False
#
#         is_warehouse  is_campsite  is_room  is_chalet  is_sell  is_rent  \
# 2308           False        False    False      False    False     True
# 2366           False        False    False      False    False     True
# 2405           False        False    False      False    False     True
# 2434           False        False    False      False    False     True
# 2435           False        False    False      False    False     True
# ...              ...          ...      ...        ...      ...      ...
# 663918         False        False    False      False    False     True
# 663924         False        False    False      False    False     True
# 663925         False        False    False      False    False     True
# 663938         False        False    False      False    False     True
# 663939         False        False    False      False    False     True
#
#        all_inclusive
# 2308            True
# 2366            True
# 2405           False
# 2434            True
# 2435            True
# ...              ...
# 663918         False
# 663924         False
# 663925         False
# 663938          True
# 663939         False
#
# [91070 rows x 40 columns]

# %% [markdown]
# ### Data Formatting

# %%
# categorical features
categorical_columns = ['rent_period', 'advertiser_type', 'daily_rentable', 'user.iam_verified']
df_processed = pd.get_dummies(df_modified, columns=categorical_columns)

# %%
df_processed[['price', 'category', 'beds', 'livings', 'wc', 'area', 'street_width',
       'age', 'street_direction', 'ketchen', 'ac', 'furnished', 'location.lat',
       'location.lng', 'user.review', 'city_id', 'district_id',
       'has_extended_details', 'number_of_rooms']]
# Out:
#           price  category  beds  livings   wc   area  street_width   age  \
# 2308     5500.0         1   1.0      1.0  1.0  160.0          18.0   2.0
# 2366     2000.0         1   3.0      1.0  1.0  160.0          18.0   0.0
# 2405    50000.0         5   7.0      2.0  5.0  900.0          30.0  30.0
# 2434     1500.0         1   1.0      1.0  1.0   50.0           5.0   2.0
# 2435     1500.0         1   1.0      1.0  1.0  160.0          18.0   2.0
# ...         ...       ...   ...      ...  ...    ...           ...   ...
# 663918  32000.0         1   4.0      2.0  2.0  160.0          23.0  10.0
# 663924  35000.0         1   3.0      1.0  2.0  160.0          18.0   9.0
# 663925  25000.0         1   3.0      1.0  2.0  125.0          18.0   2.0
# 663938  50000.0         1   2.0      2.0  2.0  250.0           5.0  15.0
# 663939  26400.0         1   4.0      1.0  3.0  150.0           5.0  17.0
#
#         street_direction  ketchen   ac  furnished  location.lat  location.lng  \
# 2308                 3.0      1.0  1.0        1.0     24.673321     46.696861
# 2366                 3.0      1.0  1.0        1.0     20.040100     41.485947
# 2405                 8.0      0.0  0.0        0.0     26.361073     43.995518
# 2434                 3.0      1.0  1.0        1.0     24.165192     47.322449
# 2435                 3.0      1.0  1.0        1.0     24.166740     47.325615
# ...                  ...      ...  ...        ...           ...           ...
# 663918               3.0      1.0  0.0        1.0     21.649360     39.139800
# 663924               3.0      1.0  0.0        0.0     21.516285     39.226463
# 663925               2.0      0.0  0.0        0.0     24.927849     46.800327
# 663938               3.0      1.0  1.0        1.0     24.795143     46.703434
# 663939               3.0      0.0  0.0        0.0     21.399612     39.299591
#
#         user.review  city_id  district_id  has_extended_details  \
# 2308           4.56       21          506                   0.0
# 2366           4.70        5         4434                   0.0
# 2405           4.74       52         2370                   0.0
# 2434           4.40       13          282                   0.0
# 2435           4.40       13          282                   0.0
# ...             ...      ...          ...                   ...
# 663918         4.46       66         3578                   0.0
# 663924         5.00       66         3604                   0.0
# 663925         4.03       21          446                   1.0
# 663938         4.49       21          522                   0.0
# 663939         4.49       66         3428                   1.0
#
#         number_of_rooms
# 2308                3.0
# 2366                5.0
# 2405               14.0
# 2434                3.0
# 2435                3.0
# ...                 ...
# 663918              8.0
# 663924              6.0
# 663925              6.0
# 663938              6.0
# 663939              8.0
#
# [91070 rows x 19 columns]
